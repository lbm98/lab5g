# %% [markdown]
# **Question:** Make a network diagram for the 5G CN - and gNodeB and UE, adding all the IP ad-
# dresses and ports (update the one from earlier).
#
# **Answer:**
# ![cn.drawio.png](attachment:e7950059-1d57-4328-9acf-fb6bfc421078.png)
#
# **Sources:**
# - https://gitlab.eurecom.fr/oai/cn5g/oai-cn5g-fed/-/blob/master/docker-compose/docker-compose-basic-nrf.yaml
# - https://gitlab.eurecom.fr/oai/openairinterface5g/-/blob/develop/targets/PROJECTS/GENERIC-NR-5GC/CONF/gnb.band78.sa.fr1.106PRB.2x2.usrpn310.conf#L202
